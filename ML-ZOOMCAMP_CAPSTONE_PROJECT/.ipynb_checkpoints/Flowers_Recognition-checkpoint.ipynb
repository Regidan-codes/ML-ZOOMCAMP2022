# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
#import needed libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from tensorflow import keras
from keras.models import load_model,Sequential
from keras.preprocessing.image import ImageDataGenerator as Imgen
from keras.preprocessing import image
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout

from PIL import Image
from sklearn.metrics import classification_report,confusion_matrix

import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 7
#       4 import pandas as pd
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#       8 sns.set_style('darkgrid')
#      10 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install split-folders --upgrade --quiet

# %%
import splitfolders
splitfolders.ratio("./flowers",output="Tr-Te-Val",ratio=(0.8,0.1,0.1))

# %% [markdown]
# ## Image data from the folders using Image Data Generator with desnet preprocessing

# %%
train_gen = Imgen(preprocessing_function=keras.applications.densenet.preprocess_input,
                 zoom_range=0.2,
                  shear_range=0.2,
                  vertical_flip=True,
                  width_shift_range=0.2,
                  height_shift_range=0.2,
                  fill_mode='nearest'
                 )

val_gen = Imgen(preprocessing_function=keras.applications.densenet.preprocess_input,
                 zoom_range=0.2,
                  shear_range=0.2,
                  vertical_flip=True,
                  width_shift_range=0.2,
                  height_shift_range=0.2,
                  fill_mode='nearest'
                 )

test_gen = Imgen(preprocessing_function=keras.applications.densenet.preprocess_input
                 )

# %%
train_ds = train_gen.flow_from_directory("./Tr-Te-Val/train",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32
                                       )

val_ds = val_gen.flow_from_directory("./Tr-Te-Val/val",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32)

test_ds = test_gen.flow_from_directory("./Tr-Te-Val/test",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32,
                                      shuffle=False
                                      )

# %%
a = train_ds.class_indices
classes = list(a.keys())
classes

# %% [markdown]
# ## Extracting one batch from datagen for visualization purposes

# %%
#one batch
X,Y = next(train_ds)

# %%
#plot function
def plot_images(img,labels):
    plt.figure(figsize=(15,10))
    for i in range(16):
        plt.subplot(4,4,i+1)
        plt.imshow(img[i])
        plt.title(classes[np.argmax(labels[i])])
        plt.axis('off')

# %%
plot_images(X,Y)

# %% [markdown]
# ## Using Transfer Learning to build the Model - model used is Desnet201

# %%
from keras.applications.densenet import DenseNet201

# %%
base_model = DenseNet201(include_top=False,
                  input_shape=(331,331,3),
                   weights = 'imagenet',
                    pooling='avg'
                  )
base_model.trainable = False

# %%
inputs = base_model.input
l1 = Dense(128,activation='relu')(base_model.output)
outputs = Dense(5,activation='softmax')(l1)
model = keras.Model(inputs=inputs,outputs=outputs)

# %%
#compile 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#callbacks
my_calls = [keras.callbacks.EarlyStopping(monitor='val_loss',patience=3),
            keras.callbacks.ModelCheckpoint("Model.h5",verbose=1,save_best_only=True)]

# %%
hist = model.fit(train_ds,epochs=18,validation_data=val_ds,callbacks=my_calls)

# %%
model = load_model("./Model.h5")

# %%
#test
model.evaluate(test_ds)

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.plot(hist.epoch,hist.history['accuracy'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_accuracy'],label = 'validation')

plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.epoch,hist.history['loss'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_loss'],label = 'validation')

plt.title("Loss")
plt.legend()
plt.show()

# %%
preds = model.predict(test_ds,verbose=1)

# %%
pred = [np.argmax(i) for i in preds]
pred[:5]

# %%
actual = test_ds.classes

# %%
print(classification_report(pred,actual))

# %%
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(pred,actual),annot = True, fmt = 'd', cmap = 'Blues');

# %% [markdown]
# ## Image data from the folders using Image Data Generator with efficientnet_v2 preprocessing

# %%
train_gen = Imgen(preprocessing_function=keras.applications.efficientnet_v2.preprocess_input,
                 zoom_range=0.2,
                  shear_range=0.2,
                  vertical_flip=True,
                  width_shift_range=0.2,
                  height_shift_range=0.2,
                  fill_mode='nearest'
                 )

val_gen = Imgen(preprocessing_function=keras.applications.efficientnet_v2.preprocess_input,
                 zoom_range=0.2,
                  shear_range=0.2,
                  vertical_flip=True,
                  width_shift_range=0.2,
                  height_shift_range=0.2,
                  fill_mode='nearest'
                 )

test_gen = Imgen(preprocessing_function=keras.applications.efficientnet_v2.preprocess_input
                 )

# %%
train_ds_1 = train_gen.flow_from_directory("./Tr-Te-Val/train",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32
                                       )

val_ds_1 = val_gen.flow_from_directory("./Tr-Te-Val/val",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32)

test_ds_1 = test_gen.flow_from_directory("./Tr-Te-Val/test",
                                       target_size=(331,331),
                                        seed = 123,
                                        batch_size=32,
                                      shuffle=False
                                      )
# Out:
# Found 3452 images belonging to 5 classes.
# Found 430 images belonging to 5 classes.
# Found 435 images belonging to 5 classes.

# %%
from keras.applications.efficientnet_v2 import EfficientNetV2S

# %%
base_model = EfficientNetV2S(include_top=False,
                  input_shape=(331,331,3),
                   weights = 'imagenet',
                    pooling='avg'
                  )
base_model.trainable = False

# %%
inputs = base_model.input
l1 = Dense(128,activation='relu')(base_model.output)
outputs = Dense(5,activation='softmax')(l1)
model = keras.Model(inputs=inputs,outputs=outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 331, 331, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 331, 331, 3)  0           ['input_2[0][0]']
#
#  stem_conv (Conv2D)             (None, 166, 166, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 166, 166, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 166, 166, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 166, 166, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 166, 166, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 166, 166, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 166, 166, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 166, 166, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 166, 166, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 166, 166, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 166, 166, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 166, 166, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 83, 83, 96)   20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 83, 83, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 83, 83, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 83, 83, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 83, 83, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 83, 83, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 83, 83, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 83, 83, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 83, 83, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 83, 83, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 83, 83, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 83, 83, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 83, 83, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 83, 83, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 83, 83, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 83, 83, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 83, 83, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 83, 83, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 83, 83, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 83, 83, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 83, 83, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 83, 83, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 83, 83, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 83, 83, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 83, 83, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 83, 83, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 42, 42, 192)  82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 42, 42, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 42, 42, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 42, 42, 64)   12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 42, 42, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 42, 42, 256)  147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 42, 42, 256)  1024       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 42, 42, 256)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 42, 42, 64)   16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 42, 42, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 42, 42, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 42, 42, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 42, 42, 256)  147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 42, 42, 256)  1024       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 42, 42, 256)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 42, 42, 64)   16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 42, 42, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 42, 42, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 42, 42, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 42, 42, 256)  147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 42, 42, 256)  1024       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 42, 42, 256)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 42, 42, 64)   16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 42, 42, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 42, 42, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 42, 42, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 42, 42, 256)  16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 42, 42, 256)  1024       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 42, 42, 256)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 21, 21, 256)  2304       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 21, 21, 256)  1024       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 21, 21, 256)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 21, 21, 256)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 21, 21, 128)  32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 21, 21, 512)  65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 21, 21, 512)  2048       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 21, 21, 512)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 21, 21, 512)  4608       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 21, 21, 512)  2048       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 21, 21, 512)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 21, 21, 512)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 21, 21, 128)  65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 21, 21, 128)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 21, 21, 128)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 21, 21, 512)  65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 21, 21, 512)  2048       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 21, 21, 512)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 21, 21, 512)  4608       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 21, 21, 512)  2048       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 21, 21, 512)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 21, 21, 512)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 21, 21, 128)  65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 21, 21, 128)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 21, 21, 128)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 21, 21, 512)  65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 21, 21, 512)  2048       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 21, 21, 512)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 21, 21, 512)  4608       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 21, 21, 512)  2048       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 21, 21, 512)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 21, 21, 512)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 21, 21, 128)  65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 21, 21, 128)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 21, 21, 128)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 21, 21, 512)  65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 21, 21, 512)  2048       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 21, 21, 512)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 21, 21, 512)  4608       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 21, 21, 512)  2048       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 21, 21, 512)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 21, 21, 512)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 21, 21, 128)  65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 21, 21, 128)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 21, 21, 128)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 21, 21, 512)  65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 21, 21, 512)  2048       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 21, 21, 512)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 21, 21, 512)  4608       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 21, 21, 512)  2048       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 21, 21, 512)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 21, 21, 512)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 21, 21, 128)  65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 21, 21, 128)  512        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 21, 21, 128)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 21, 21, 128)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 21, 21, 768)  98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 21, 21, 768)  3072       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 21, 21, 768)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 21, 21, 768)  6912       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 21, 21, 768)  3072       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 21, 21, 768)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 21, 21, 768)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 21, 21, 160)  122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 21, 21, 160)  640        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 21, 21, 960)  153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 21, 21, 960)  3840       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 21, 21, 960)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 21, 21, 960)  8640       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 21, 21, 960)  3840       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 21, 21, 960)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 21, 21, 960)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 21, 21, 160)  153600      ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 21, 21, 160)  640        ['block5b_project_conv[0][0]']
#  lization)
#
# ...
#  block6l_se_squeeze (GlobalAver  (None, 1536)        0           ['block6l_activation[0][0]']
#  agePooling2D)
#
#  block6l_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6l_se_squeeze[0][0]']
#
#  block6l_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multiply)   (None, 11, 11, 1536  0           ['block6l_activation[0][0]',
#                                 )                                 'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv2D)  (None, 11, 11, 256)  393216      ['block6l_se_excite[0][0]']
#
#  block6l_project_bn (BatchNorma  (None, 11, 11, 256)  1024       ['block6l_project_conv[0][0]']
#  lization)
#
#  block6l_drop (Dropout)         (None, 11, 11, 256)  0           ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)              (None, 11, 11, 256)  0           ['block6l_drop[0][0]',
#                                                                   'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2D)   (None, 11, 11, 1536  393216      ['block6l_add[0][0]']
#                                 )
#
#  block6m_expand_bn (BatchNormal  (None, 11, 11, 1536  6144       ['block6m_expand_conv[0][0]']
#  ization)                       )
#
#  block6m_expand_activation (Act  (None, 11, 11, 1536  0          ['block6m_expand_bn[0][0]']
#  ivation)                       )
#
#  block6m_dwconv2 (DepthwiseConv  (None, 11, 11, 1536  13824      ['block6m_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6m_bn (BatchNormalization  (None, 11, 11, 1536  6144       ['block6m_dwconv2[0][0]']
#  )                              )
#
#  block6m_activation (Activation  (None, 11, 11, 1536  0          ['block6m_bn[0][0]']
#  )                              )
#
#  block6m_se_squeeze (GlobalAver  (None, 1536)        0           ['block6m_activation[0][0]']
#  agePooling2D)
#
#  block6m_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6m_se_squeeze[0][0]']
#
#  block6m_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multiply)   (None, 11, 11, 1536  0           ['block6m_activation[0][0]',
#                                 )                                 'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv2D)  (None, 11, 11, 256)  393216      ['block6m_se_excite[0][0]']
#
#  block6m_project_bn (BatchNorma  (None, 11, 11, 256)  1024       ['block6m_project_conv[0][0]']
#  lization)
#
#  block6m_drop (Dropout)         (None, 11, 11, 256)  0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)              (None, 11, 11, 256)  0           ['block6m_drop[0][0]',
#                                                                   'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)   (None, 11, 11, 1536  393216      ['block6m_add[0][0]']
#                                 )
#
#  block6n_expand_bn (BatchNormal  (None, 11, 11, 1536  6144       ['block6n_expand_conv[0][0]']
#  ization)                       )
#
#  block6n_expand_activation (Act  (None, 11, 11, 1536  0          ['block6n_expand_bn[0][0]']
#  ivation)                       )
#
#  block6n_dwconv2 (DepthwiseConv  (None, 11, 11, 1536  13824      ['block6n_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6n_bn (BatchNormalization  (None, 11, 11, 1536  6144       ['block6n_dwconv2[0][0]']
#  )                              )
#
#  block6n_activation (Activation  (None, 11, 11, 1536  0          ['block6n_bn[0][0]']
#  )                              )
#
#  block6n_se_squeeze (GlobalAver  (None, 1536)        0           ['block6n_activation[0][0]']
#  agePooling2D)
#
#  block6n_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)   (None, 11, 11, 1536  0           ['block6n_activation[0][0]',
#                                 )                                 'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)  (None, 11, 11, 256)  393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNorma  (None, 11, 11, 256)  1024       ['block6n_project_conv[0][0]']
#  lization)
#
#  block6n_drop (Dropout)         (None, 11, 11, 256)  0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)              (None, 11, 11, 256)  0           ['block6n_drop[0][0]',
#                                                                   'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)   (None, 11, 11, 1536  393216      ['block6n_add[0][0]']
#                                 )
#
#  block6o_expand_bn (BatchNormal  (None, 11, 11, 1536  6144       ['block6o_expand_conv[0][0]']
#  ization)                       )
#
#  block6o_expand_activation (Act  (None, 11, 11, 1536  0          ['block6o_expand_bn[0][0]']
#  ivation)                       )
#
#  block6o_dwconv2 (DepthwiseConv  (None, 11, 11, 1536  13824      ['block6o_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6o_bn (BatchNormalization  (None, 11, 11, 1536  6144       ['block6o_dwconv2[0][0]']
#  )                              )
#
#  block6o_activation (Activation  (None, 11, 11, 1536  0          ['block6o_bn[0][0]']
#  )                              )
#
#  block6o_se_squeeze (GlobalAver  (None, 1536)        0           ['block6o_activation[0][0]']
#  agePooling2D)
#
#  block6o_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)   (None, 11, 11, 1536  0           ['block6o_activation[0][0]',
#                                 )                                 'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)  (None, 11, 11, 256)  393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNorma  (None, 11, 11, 256)  1024       ['block6o_project_conv[0][0]']
#  lization)
#
#  block6o_drop (Dropout)         (None, 11, 11, 256)  0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)              (None, 11, 11, 256)  0           ['block6o_drop[0][0]',
#                                                                   'block6n_add[0][0]']
#
#  top_conv (Conv2D)              (None, 11, 11, 1280  327680      ['block6o_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 11, 11, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 11, 11, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  dense_2 (Dense)                (None, 128)          163968      ['avg_pool[0][0]']
#
#  dense_3 (Dense)                (None, 5)            645         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 20,495,973
# Trainable params: 164,613
# Non-trainable params: 20,331,360
# __________________________________________________________________________________________________

# %%
#compile 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#callbacks
my_calls = [keras.callbacks.EarlyStopping(monitor='val_loss',patience=3),
            keras.callbacks.ModelCheckpoint("Model_2.h5",verbose=1,save_best_only=True)]

# %%
hist = model.fit(train_ds_1,epochs=18,validation_data=val_ds_1,callbacks=my_calls)
# Out:
# Epoch 1/18
# 2022-12-21 06:18:13.297327: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-12-21 06:18:13.985402: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-12-21 06:18:13.986423: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-12-21 06:18:13.986460: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-12-21 06:18:13.987491: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-12-21 06:18:13.987581: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 108/108 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8218
# Epoch 1: val_loss improved from inf to 0.25942, saving model to Model_2.h5
# 108/108 [==============================] - 115s 930ms/step - loss: 0.4848 - accuracy: 0.8218 - val_loss: 0.2594 - val_accuracy: 0.9140
# Epoch 2/18
# 108/108 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8986
# Epoch 2: val_loss did not improve from 0.25942
# 108/108 [==============================] - 95s 877ms/step - loss: 0.2900 - accuracy: 0.8986 - val_loss: 0.2610 - val_accuracy: 0.9116
# Epoch 3/18
# 108/108 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9134
# Epoch 3: val_loss improved from 0.25942 to 0.22682, saving model to Model_2.h5
# 108/108 [==============================] - 96s 889ms/step - loss: 0.2535 - accuracy: 0.9134 - val_loss: 0.2268 - val_accuracy: 0.9326
# Epoch 4/18
# 108/108 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9163
# Epoch 4: val_loss did not improve from 0.22682
# 108/108 [==============================] - 94s 873ms/step - loss: 0.2347 - accuracy: 0.9163 - val_loss: 0.2557 - val_accuracy: 0.9093
# Epoch 5/18
# 108/108 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9311
# Epoch 5: val_loss did not improve from 0.22682
# 108/108 [==============================] - 95s 878ms/step - loss: 0.2052 - accuracy: 0.9311 - val_loss: 0.2403 - val_accuracy: 0.9279
# Epoch 6/18
# 108/108 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9299
# Epoch 6: val_loss did not improve from 0.22682
# 108/108 [==============================] - 95s 876ms/step - loss: 0.1884 - accuracy: 0.9299 - val_loss: 0.2583 - val_accuracy: 0.9070

# %%
model = load_model("./Model_2.h5")

# %%
#test
model.evaluate(test_ds_1)
# Out:
# 14/14 [==============================] - 8s 311ms/step - loss: 0.2165 - accuracy: 0.9264
# [0.2164650559425354, 0.9264367818832397]

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.plot(hist.epoch,hist.history['accuracy'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_accuracy'],label = 'validation')

plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.epoch,hist.history['loss'],label = 'Training')
plt.plot(hist.epoch,hist.history['val_loss'],label = 'validation')

plt.title("Loss")
plt.legend()
plt.show()

# %%
preds = model.predict(test_ds_1,verbose=1)
# Out:
# 14/14 [==============================] - 6s 239ms/step

# %%
actual = test_ds_1.classes

# %%
pred = [np.argmax(i) for i in preds]
pred[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
print(classification_report(pred,actual))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        81
#            1       0.94      0.96      0.95       104
#            2       0.91      0.90      0.91        80
#            3       0.93      0.93      0.93        74
#            4       0.90      0.93      0.91        96
#
#     accuracy                           0.93       435
#    macro avg       0.93      0.92      0.93       435
# weighted avg       0.93      0.93      0.93       435
